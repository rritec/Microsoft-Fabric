# %% [markdown]
# # 1️⃣ Read Bronze data

# %%
from pyspark.sql.functions import (
    col, to_date, trim, coalesce, lit, when
)

# Read Bronze data from Files
dept_bronze_df = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv("Files/bronze/dept.csv")
)

# Preview data 
dept_bronze_df.printSchema()
dept_bronze_df.show(5)
# Out:
# StatementMeta(, 0dab813e-4b62-4ae2-b9e8-6e334dd7ab49, 4, Finished, Available, Finished)
# root
#  |-- deptno: integer (nullable = true)
#  |-- dname: string (nullable = true)
#  |-- loc: string (nullable = true)
#
# +------+----------+--------+
# |deptno|     dname|     loc|
# +------+----------+--------+
# |    10|ACCOUNTING|NEW YORK|
# |    20|  RESEARCH|  DALLAS|
# |    30|     SALES| CHICAGO|
# |    40|OPERATIONS|  BOSTON|
# +------+----------+--------+

# %% [markdown]
# # 2️⃣ Apply transformations(Not Applicable/Required)

# %% [markdown]
# # 3. Write to Silver layer (Delta)

# %%
dept_bronze_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver.silver_dept")
# Out:
# StatementMeta(, 0dab813e-4b62-4ae2-b9e8-6e334dd7ab49, 6, Finished, Available, Finished)
