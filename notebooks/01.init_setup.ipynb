# %%
trg_table_name = 'tgt_incr_emp'
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 3, Finished, Available, Finished)

# %%
# %%sql
# DROP TABLE IF EXISTS dbo.src_incr_emp;
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# create or replace table dbo.src_incr_emp
# (
#     empid int,
#     ename varchar(255),
#     hiredate timestamp
# );
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 5, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO dbo.src_incr_emp
#     (empid, ename, hiredate)
# VALUES
#     (1, 'Myla RamReddy', to_timestamp('9/1/2020 12:56:00 AM', 'M/d/yyyy h:mm:ss a')),
#     (2, 'Anam Tarun', to_timestamp('9/2/2020 5:23:00 AM', 'M/d/yyyy h:mm:ss a')),
#     (3, 'John', to_timestamp('9/3/2020 2:36:00 AM', 'M/d/yyyy h:mm:ss a')),
#     (4, 'Mark', to_timestamp('9/4/2020 3:21:00 AM', 'M/d/yyyy h:mm:ss a')),
#     (5, 'Nancy', to_timestamp('9/5/2020 8:06:00 AM', 'M/d/yyyy h:mm:ss a'));
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 6, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from dbo.src_incr_emp
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 7, Finished, Available, Finished)
# <Spark SQL result set with 5 rows and 3 fields>

# %%
# %%sql
# DROP TABLE IF EXISTS dbo.watermarktable;
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 8, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# create table dbo.watermarktable
# (
#
# TableName varchar(255),
# last_load_date TIMESTAMP
# );
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 9, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# INSERT INTO watermarktable
# VALUES ('tgt_incr_emp', to_timestamp('1/1/1900 12:00:00 AM', 'M/d/yyyy h:mm:ss a'));
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 10, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from dbo.watermarktable
# Out:
# StatementMeta(, 56f9d108-cea5-4768-99e5-c35a3ffef69e, 11, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>
