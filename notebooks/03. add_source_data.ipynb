# %%
# %%sql
#
# INSERT INTO src_incr_emp
#     (empid, ename, hiredate)
# VALUES
#     (6, 'geo', to_timestamp('9/6/2020 2:23:00 AM', 'M/d/yyyy h:mm:ss a')),
#     (7, 'albert', to_timestamp('9/7/2020 9:01:00 AM', 'M/d/yyyy h:mm:ss a'));
# Out:
# StatementMeta(, 85497f16-e392-493b-81f6-63fe08e11b44, 12, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %run ./Actual_code
# Out:
# StatementMeta(, 85497f16-e392-493b-81f6-63fe08e11b44, 20, Finished, Available, Finished)
# Max hiredate: 2020-09-07 09:01:00
# Last load date: None
# "\nSELECT * FROM dbo.src_incr_emp\nWHERE hiredate >= to_timestamp('None', 'yyyy-MM-dd HH:mm:ss')\n  AND hiredate < to_timestamp('2020-09-07 09:01:00', 'yyyy-MM-dd HH:mm:ss')\n"
# +-----+-------------+-------------------+
# |empid|        ename|           hiredate|
# +-----+-------------+-------------------+
# |    3|         John|2020-09-03 02:36:00|
# |    4|         Mark|2020-09-04 03:21:00|
# |    1|Myla RamReddy|2020-09-01 00:56:00|
# |    2|   Anam Tarun|2020-09-02 05:23:00|
# +-----+-------------+-------------------+
# DataFrame[num_affected_rows: bigint]
# <Spark SQL result set with 1 rows and 2 fields>
