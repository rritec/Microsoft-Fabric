# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

import First_module as fm
# Out:
# StatementMeta(, 990de362-a2c0-4da3-a298-aaf82f72dafd, 3, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Welcome to your new notebook
#       2 # Type here in the cell editor to add code!
# ----> 4 import First_module as fm
#
# ModuleNotFoundError: No module named 'First_module'

# %%
import sys
sys.path.append('/lakehouse/default/Files')
# Out:
# StatementMeta(, 990de362-a2c0-4da3-a298-aaf82f72dafd, 4, Finished, Available, Finished)

# %%
import First_module as fm
# Out:
# StatementMeta(, 990de362-a2c0-4da3-a298-aaf82f72dafd, 5, Finished, Available, Finished)

# %%
fm.a
# Out:
# StatementMeta(, 990de362-a2c0-4da3-a298-aaf82f72dafd, 6, Finished, Available, Finished)
# 10

# %%
fm.b
# Out:
# StatementMeta(, 990de362-a2c0-4da3-a298-aaf82f72dafd, 7, Finished, Available, Finished)
# 10.33
